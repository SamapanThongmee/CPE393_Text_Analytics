# %% [markdown]
# Tutorial on YouTube Chanel:
# การสร้าง Web Scraper | Building Web Scraper | Lecture 4
# https://youtu.be/HBnHQF2reRU?si=T6aJP43AHwocVHct

# %% [markdown]
# ##### <b>Downloading and interoretingrobot.txt</b>

# %%
from urllib.request import urlopen
res = urlopen("https://www.reuters.com/robots.txt")
print(res.read().decode('utf-8'))
# Out:
# # robots.txt for www.reuters.com
#
# User-agent: PiplBot
# Disallow: /
#
# User-agent: CCbot
# Disallow: /
#
# User-agent: anthropic-ai
# Disallow: /
#
# User-agent: Claude-Web
# Disallow: /
#
# User-agent: Google-Extended
# Disallow: /
#
# User-agent: FacebookBot
# Disallow: /
#
# User-agent: *
# Disallow: /finance/stocks/option
# Disallow: /finance/stocks/financialHighlights
# Disallow: /search
# Disallow: /site-search/
# Disallow: /beta
# Disallow: /designtech
# Disallow: /featured-optimize
# Disallow: /energy-test
# Disallow: /article/beta
# Disallow: /sponsored/previewcampaign
# Disallow: /sponsored/previewarticle
# Disallow: /test/
# Disallow: /commentary
# Disallow: /news/archive/commentary
# Disallow: /brandfeatures/venture-capital
# Disallow: /journalists/
# Disallow: /assets/siteindex
# Disallow: /article/api/
# Disallow: /practical-law-the-journal/search/
# Disallow: /practical-law-the-journal/contributors/
# Disallow: /fr/
#
# ...

# %%
import urllib.robotparser

rp = urllib.robotparser.RobotFileParser()
rp.set_url("https://www.reuters.com/robots.txt")
rp.read()
rp.can_fetch("*", ("https://www.reuters.com/sitemap.xml"))
# Out:
# True

# %%
rp.site_maps()
# Out:
# ['https://www.reuters.com/arc/outboundfeeds/sitemap-index/?outputType=xml',
#  'https://www.reuters.com/arc/outboundfeeds/news-sitemap-index/?outputType=xml',
#  'https://www.reuters.com/sitemap_video_index.xml',
#  'https://www.reuters.com/plus/sitemap-index.xml',
#  'https://www.reuters.com/arc/outboundfeeds/sitemap-plj-index/?outputType=xml',
#  'https://www.reuters.com/graphics/sitemap.xml']

# %% [markdown]
# ##### <b>Find URLs from sitemap.xml</b>

# %%
# !pip install --upgrade certifi
# !pip install --upgrade requests
# Out:
# ...
#      ------------------------------------- 158.3/158.3 kB 27.2 kB/s eta 0:00:00
# ...
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2022.9.14
#     Uninstalling certifi-2022.9.14:
#       Successfully uninstalled certifi-2022.9.14
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
# ...
#      -------------------------------------- 62.6/62.6 kB 239.0 kB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
# ...

# %%
import xmltodict
import requests

sitemap = xmltodict.parse(requests.get(rp.site_maps()[0], verify=False).text)
# Out:
# c:\Users\samapant\Anaconda3\Anaconda\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.reuters.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
sitemap.keys()
# Out:
# dict_keys(['sitemapindex'])

# %%
import pandas as pd
sitemap_link_df = pd.DataFrame.from_dict(sitemap['sitemapindex']['sitemap'])
sitemap_link_df.head()
# Out:
#                                                  loc                   lastmod
# 0  https://www.reuters.com/arc/outboundfeeds/site...  2023-11-09T20:30:56.766Z
# 1  https://www.reuters.com/arc/outboundfeeds/site...  2023-11-09T20:30:56.766Z
# 2  https://www.reuters.com/arc/outboundfeeds/site...  2023-11-09T20:30:56.766Z
# 3  https://www.reuters.com/arc/outboundfeeds/site...  2023-11-09T20:30:56.766Z
# 4  https://www.reuters.com/arc/outboundfeeds/site...  2023-11-09T20:30:56.766Z

# %%
sitemap_link_df.shape
# Out:
# (128, 2)

# %% [markdown]
# ##### <b>Find URLs from RSS</b>

# %%
# !pip install feedparser
# Out:
# ...
#      -------------------------------------- 81.1/81.1 kB 267.4 kB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6048 sha256=c38ce041719ce468fb289e6d62a6cfa86f742cf833bb4a3dc72bec0ccbd5de9d
#   Stored in directory: c:\users\samapant\appdata\local\pip\cache\wheels\65\7a\a7\78c287f64e401255dff4c13fdbc672fed5efbfd21c530114e1
# Successfully built sgmllib3k
# ...

# %%
import feedparser
feed = feedparser.parse('https://feeds.bbci.co.uk/news/rss.xml')
feed
# Out:
# {'bozo': False,
#  'entries': [{'title': 'No 10 disowns Suella Braverman article attacking police over protests',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/rss.xml',
#     'value': 'No 10 disowns Suella Braverman article attacking police over protests'},
#    'summary': 'The home secretary is facing questions about her future over her incendiary article about protests.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/rss.xml',
#     'value': 'The home secretary is facing questions about her future over her incendiary article about protests.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.co.uk/news/uk-politics-67368785?at_medium=RSS&at_campaign=KARANGA'}],
#    'link': 'https://www.bbc.co.uk/news/uk-politics-67368785?at_medium=RSS&at_campaign=KARANGA',
# ...

# %%
pd.DataFrame.from_dict(feed['entries'])
# Out:
#                                                 title  \
# 0   No 10 disowns Suella Braverman article attacki...
# 1   Chris Mason: Is Suella Braverman facing the sack?
# 2   Footballer Luis Díaz's father freed by Colombi...
# 3    Dramatic car chase on M6 motorway ends in arrest
# 4   Strictly Come Dancing: Amy Dowden rings bell a...
# ..                                                ...
# 70  Interest rates: How the Bank of England's deci...
# 71    How to save money even when the budget is tight
# 72   Debt: What should I pay first and what can I do?
# 73  How to get a job: Six expert tips for finding ...
# 74                What is GDP and how is it measured?
#
#                                          title_detail  \
# 0   {'type': 'text/plain', 'language': None, 'base...
# 1   {'type': 'text/plain', 'language': None, 'base...
# 2   {'type': 'text/plain', 'language': None, 'base...
# 3   {'type': 'text/plain', 'language': None, 'base...
# ...

# %%
[w for w in tokens if re.search('^[bdf][aue][rts]$', w)]
# Out:
# ['but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'far',
#  'but',
#  'but',
#  'but',
#  'but',
#  'fur',
#  'far',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'fat',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
#  'but',
# ...

# %%
[w for w in tokens if re.search('noo+$', w)]
# Out:
# []

# %%
[w for w in tokens if re.search('noo*$', w)]
# Out:
# ['no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
# ...

# %%
[w for w in tokens if re.search('\.+$', w)]
# Out:
# ['.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'folk.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'press.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'lives.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'king.',
#  '.',
#  '...',
#  '.',
#  'great.',
#  's.',
#  'k.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '...',
#  '.',
#  '.',
#  '....',
#  '.',
#  '.',
#  '.',
#  '...',
#  '.',
#  '.',
#  'plaything.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '....',
#  '....',
#  '.',
#  '....',
#  '.',
#  '....',
#  '....',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '....',
#  '.',
#  '.',
#  '.',
# ...

# %%
[w for w in tokens if re.search('^[0-9]{4}$', w)]
# Out:
# ['2001',
#  '2554',
#  '2021',
#  '1849',
#  '1859',
#  '1864',
#  '1880',
#  '1861',
#  '2001',
#  '1500']

# %%
nltk.download('treebank')
wsj = sorted(set(nltk.corpus.treebank.words()))
[w for w in wsj if re.search('^[0-9]+-[a-z]{3,5}$', w)]
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\samapant\AppData\Roaming\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# ['10-day',
#  '10-lap',
#  '10-year',
#  '100-share',
#  '12-point',
#  '12-year',
#  '14-hour',
#  '15-day',
#  '150-point',
#  '190-point',
#  '20-point',
#  '20-stock',
#  '21-month',
#  '237-seat',
#  '240-page',
#  '27-year',
#  '30-day',
#  '30-point',
#  '30-share',
#  '30-year',
#  '300-day',
#  '36-day',
#  '36-store',
#  '42-year',
#  '50-state',
#  '500-stock',
#  '52-week',
#  '69-point',
#  '84-month',
#  '87-store',
#  '90-day']

# %%
[w for w in wsj if re.search('^[a-z]{5,}-[a-z]{2,3}-[a-z]{,6}$', w)]
# Out:
# ['black-and-white',
#  'bread-and-butter',
#  'father-in-law',
#  'machine-gun-toting',
#  'savings-and-loan']

# %%
set([w for w in tokens if re.search('(ed|ing)$', w)])
# Out:
# {'oppressed',
#  'protested',
#  'craved',
#  'translated',
#  'staying',
#  'teaching',
#  'raving',
#  'filled',
#  'quaking',
#  'loathing',
#  'infected',
#  'washing',
#  'long-winded',
#  'leaping',
#  'bearing',
#  'tear-stained',
#  'shamefaced',
#  'ever-burning',
#  'condescending',
#  'overflowing',
#  'arguing',
#  'separated',
#  'wrapping',
#  'stepped',
#  'unfolded',
#  'updated',
#  'unbelieving',
#  'overlooked',
#  'embarrassed',
#  'acquiring',
#  'insured',
#  'dejected',
#  'confounded',
#  'interrupted',
#  'hooked',
#  'cockaded',
#  'seeming',
#  'chased',
#  'renounced',
#  'centered',
#  'blundering',
#  'following',
#  'streamed',
#  'spring',
#  'betraying',
#  'displaying',
#  'reminding',
#  'pondered',
#  'neighbouring',
#  'commenced',
#  'hindered',
#  'ventured',
#  'passed',
#  'refined',
#  'flagging',
#  'accompanied',
#  'proceeding',
#  'begging',
#  'devouring',
#  'distracted',
#  'short-sighted',
#  'outraged',
#  'worked',
#  'blessed',
# ...

# %% [markdown]
# ##### <b>Regular Expression Tokenizer</b>

# %%
s1 = ("Good muffins cost $3.88\nin New York. Please buy me\n"
     "two of them.\n\nThanks.")

s2 = ("Alas, it has not reained today. When, do you think, "
      "will it rain again?")

s3 = ("<p>Although this is <b>not</b> the case here, we must "
      "not relax our cigilance!</p>")

# %%
s1
# Out:
# 'Good muffins cost $3.88\nin New York. Please buy me\ntwo of them.\n\nThanks.'

# %%
nltk.regexp_tokenize(s1, r'[,\.\?!"]\s*', gaps=True)
# Out:
# ['Good muffins cost $3',
#  '88\nin New York',
#  'Please buy me\ntwo of them',
#  'Thanks']

# %%
s2
# Out:
# 'Alas, it has not reained today. When, do you think, will it rain again?'

# %%
nltk.regexp_tokenize(s2, r'[,\.\?!"]\s*', gaps=True)
# Out:
# ['Alas',
#  'it has not reained today',
#  'When',
#  'do you think',
#  'will it rain again']

# %%
s3
# Out:
# '<p>Although this is <b>not</b> the case here, we must not relax our cigilance!</p>'

# %%
nltk.regexp_tokenize(s3, r'</?.>', gaps=False)
# Out:
# ['<p>', '<b>', '</b>', '</p>']

# %%
nltk.regexp_tokenize(s3, r'</?.>', gaps=True)
# Out:
# ['Although this is ',
#  'not',
#  ' the case here, we must not relax our cigilance!']

# %%
import re

regex = r"\.(jpg|png|JPG|PNG)$"

# %%
tokenizer = nltk.RegexpTokenizer(r"\w+")
tokens_0 = tokenizer.tokenize(raw)
print(tokens_0[1000:1100])
# Out:
# ['roof', 'of', 'a', 'high', 'five', 'storied', 'house', 'and', 'was', 'more', 'like', 'a', 'cupboard', 'than', 'a', 'room', 'The', 'landlady', 'who', 'provided', 'him', 'with', 'garret', 'dinners', 'and', 'attendance', 'lived', 'on', 'the', 'floor', 'below', 'and', 'every', 'time', 'he', 'went', 'out', 'he', 'was', 'obliged', 'to', 'pass', 'her', 'kitchen', 'the', 'door', 'of', 'which', 'invariably', 'stood', 'open', 'And', 'each', 'time', 'he', 'passed', 'the', 'young', 'man', 'had', 'a', 'sick', 'frightened', 'feeling', 'which', 'made', 'him', 'scowl', 'and', 'feel', 'ashamed', 'He', 'was', 'hopelessly', 'in', 'debt', 'to', 'his', 'landlady', 'and', 'was', 'afraid', 'of', 'meeting', 'her', 'This', 'was', 'not', 'because', 'he', 'was', 'cowardly', 'and', 'abject', 'quite', 'the', 'contrary', 'but', 'for', 'some']

# %%
# case normalization

tokens = [w.lower() for w in tokens]
tokens
# Out:
# ['the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'crime',
#  'and',
#  'punishment',
#  ',',
#  'by',
#  'fyodor',
#  'dostoevsky',
#  'this',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'united',
#  'states',
#  'and',
#  'most',
#  'other',
#  'parts',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  '.',
#  'you',
#  'may',
#  'copy',
#  'it',
#  ',',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'license',
#  'included',
#  'with',
#  'this',
#  'ebook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.org',
#  '.',
#  'if',
#  'you',
#  'are',
#  'not',
#  'located',
#  'in',
#  'the',
#  'united',
#  'states',
#  ',',
#  'you',
#  'will',
#  'have',
#  'to',
#  'check',
#  'the',
#  'laws',
#  'of',
# ...

# %%
# Replacing \xad

set([w.replace('\xad','') for w in tokens if w.startswith('gry')])
token_1 = [w.replace('\xad','') for w in tokens]
print(token_1[1000:1100])
# Out:
# ['man', 'of', 'our', 'blood', 'and', 'our', 'bone', ',', 'but', 'one', 'who', 'has', 'suffered', 'and', 'has', 'seen', 'so', 'much', 'more', 'deeply', 'than', 'we', 'have', 'his', 'insight', 'impresses', 'us', 'as', 'wisdom', '...', 'that', 'wisdom', 'of', 'the', 'heart', 'which', 'we', 'seek', 'that', 'we', 'may', 'learn', 'from', 'it', 'how', 'to', 'live', '.', 'all', 'his', 'other', 'gifts', 'came', 'to', 'him', 'from', 'nature', ',', 'this', 'he', 'won', 'for', 'himself', 'and', 'through', 'it', 'he', 'became', 'great.', '”', 'crime', 'and', 'punishment', 'part', 'i', 'chapter', 'i', 'on', 'an', 'exceptionally', 'hot', 'evening', 'early', 'in', 'july', 'a', 'young', 'man', 'came', 'out', 'of', 'the', 'garret', 'in', 'which', 'he', 'lodged', 'in', 's.', 'place']

# %%
# Stemming

porter = nltk.PorterStemmer()
token_2 = [porter.stem(t) for t in token_1]
print(token_2[1000:1100])
# Out:
# ['man', 'of', 'our', 'blood', 'and', 'our', 'bone', ',', 'but', 'one', 'who', 'ha', 'suffer', 'and', 'ha', 'seen', 'so', 'much', 'more', 'deepli', 'than', 'we', 'have', 'hi', 'insight', 'impress', 'us', 'as', 'wisdom', '...', 'that', 'wisdom', 'of', 'the', 'heart', 'which', 'we', 'seek', 'that', 'we', 'may', 'learn', 'from', 'it', 'how', 'to', 'live', '.', 'all', 'hi', 'other', 'gift', 'came', 'to', 'him', 'from', 'natur', ',', 'thi', 'he', 'won', 'for', 'himself', 'and', 'through', 'it', 'he', 'becam', 'great.', '”', 'crime', 'and', 'punish', 'part', 'i', 'chapter', 'i', 'on', 'an', 'except', 'hot', 'even', 'earli', 'in', 'juli', 'a', 'young', 'man', 'came', 'out', 'of', 'the', 'garret', 'in', 'which', 'he', 'lodg', 'in', 's.', 'place']

# %%
# Lemmatization

# wordnnet lemmatizer

import nltk
nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\samapant\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\samapant\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
wnl = nltk.WordNetLemmatizer()

print('rocks', wnl.lemmatize('rocks'))
print('corpora', wnl.lemmatize('co'))
print('running', wnl.lemmatize('running', pos='v'))
# Out:
# rocks rock
# corpora co
# running run

# %%
# Listing stopwords
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
print('Stopwords', stop_words)
print('Numer of stopwords: ', len(stop_words))
# Out:
# Stopwords {'below', 'ours', 'more', 'which', 'my', 'after', 'mustn', 'the', 'when', 'he', 'and', 'our', 'what', 'into', 'was', 'wasn', 'their', "won't", 'shan', 'as', 'this', 'his', 'needn', 'your', 'a', "you've", 'from', "hasn't", 'that', 'above', 'until', 'hasn', "isn't", 'been', 'now', 'haven', 'why', "mightn't", 'them', 'both', "wasn't", 'be', 'were', 'before', "hadn't", 'not', 'o', 'am', 'too', 'him', 'an', 'with', 'm', 'under', 'out', 'no', 'or', "didn't", 'her', 'didn', 'its', 'than', 'by', 'ma', 'himself', "shan't", 'have', "should've", 'yourself', "that'll", 'aren', 'themselves', 'had', "you'd", 'couldn', 'if', 'theirs', 'while', 'at', 'only', 'mightn', 't', 're', 'nor', 'having', 'wouldn', "she's", 'did', 'doesn', 'y', "mustn't", 'just', "wouldn't", 'can', 'being', 'here', 'few', 'once', "doesn't", 'further', 'down', 'where', 'it', 'because', 'ourselves', 'such', 'hadn', "you'll", 'she', 'doing', 'you', 'll', 'but', 'does', 'myself', 'same', 'weren', 'each', 'there', 'won',
# ...

# %%
token_4 = [w for w in tokens if not w in stop_words]
print(tokens[1000:1100])
print(token_4[1000:1100])
# Out:
# ['man', 'of', 'our', 'blood', 'and', 'our', 'bone', ',', 'but', 'one', 'who', 'has', 'suffered', 'and', 'has', 'seen', 'so', 'much', 'more', 'deeply', 'than', 'we', 'have', 'his', 'insight', 'impresses', 'us', 'as', 'wisdom', '...', 'that', 'wisdom', 'of', 'the', 'heart', 'which', 'we', 'seek', 'that', 'we', 'may', 'learn', 'from', 'it', 'how', 'to', 'live', '.', 'all', 'his', 'other', 'gifts', 'came', 'to', 'him', 'from', 'nature', ',', 'this', 'he', 'won', 'for', 'himself', 'and', 'through', 'it', 'he', 'became', 'great.', '”', 'crime', 'and', 'punishment', 'part', 'i', 'chapter', 'i', 'on', 'an', 'exceptionally', 'hot', 'evening', 'early', 'in', 'july', 'a', 'young', 'man', 'came', 'out', 'of', 'the', 'garret', 'in', 'which', 'he', 'lodged', 'in', 's.', 'place']
# ...

# %%
# Part of Speech (POS) tagging
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\samapant\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
tokens_5 = nltk.pos_tag(tokens)

# %%
tokens_5[1000:1100]
# Out:
# [('man', 'NN'),
#  ('of', 'IN'),
#  ('our', 'PRP$'),
#  ('blood', 'NN'),
#  ('and', 'CC'),
#  ('our', 'PRP$'),
#  ('bone', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('one', 'CD'),
#  ('who', 'WP'),
#  ('has', 'VBZ'),
#  ('suffered', 'VBN'),
#  ('and', 'CC'),
#  ('has', 'VBZ'),
#  ('seen', 'VBN'),
#  ('so', 'RB'),
#  ('much', 'RB'),
#  ('more', 'JJR'),
#  ('deeply', 'RB'),
#  ('than', 'IN'),
#  ('we', 'PRP'),
#  ('have', 'VBP'),
#  ('his', 'PRP$'),
#  ('insight', 'NN'),
#  ('impresses', 'VBZ'),
#  ('us', 'PRP'),
#  ('as', 'IN'),
#  ('wisdom', 'NN'),
#  ('...', ':'),
#  ('that', 'IN'),
#  ('wisdom', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('heart', 'NN'),
#  ('which', 'WDT'),
#  ('we', 'PRP'),
#  ('seek', 'VBP'),
#  ('that', 'IN'),
#  ('we', 'PRP'),
#  ('may', 'MD'),
#  ('learn', 'VB'),
#  ('from', 'IN'),
#  ('it', 'PRP'),
#  ('how', 'WRB'),
#  ('to', 'TO'),
#  ('live', 'VB'),
#  ('.', '.'),
#  ('all', 'DT'),
#  ('his', 'PRP$'),
#  ('other', 'JJ'),
#  ('gifts', 'NNS'),
# ...

# %% [markdown]
# ##### <b>Homework</b>

# %% [markdown]
# Use the UN General Debates dataset

# %%
# Explore the pattern
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import regexp_tokenize
from collections import Counter

import nltk
nltk.download('stopwords')
nltk.download('punkt')

stop_words = set(stopwords.words('english'))

df = pd.read_csv('un-general-debates.csv')
df.sample(10)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\samapant\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\samapant\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#       session  year country                                               text
# 4416       58  2003     ETH  ﻿It gives me great pleasure\nto extend to Juli...
# 4247       53  1998     TGO  Allow me first of all, on behalf of the people...
# 993        41  1986     VCT   On behalf of the Government and people of Sai...
# 4467       58  2003     MKD  ﻿I am greatly honoured to\naddress this distin...
# 6099       55  2000     NER   wish at\nthe very outset to convey to the cou...
# 5860       32  1977     SYR  ﻿181.\tMr. President, may I first of all warml...
# 6679       49  1994     USA  Let me first congratulate you, Mr.\nPresident,...
# ...

# %%
# Tokens Column
df['tokens'] = df['text'].apply(word_tokenize)

# Remove stopwords from tokens in the DataFrame
df['tokens_no_stopwords'] = df['tokens'].apply(lambda tokens: [token for token in tokens if token.lower() not in stop_words])

# Tokenize text using NLTK regexp_tokenize
pattern = r'[,\.\?!"]\s*'
df['tokens_regexp'] = df['text'].apply(lambda x: regexp_tokenize(x, pattern, gaps=True))

# %%
def ngram(tokens, n=2, sep=' ', stopwords=set()):
    return [sep.join(ngram) for ngram in zip(*[tokens[i:] for i in range(n)])
            if len([t for t in ngram if t in stopwords])==0]

# %%
# pass ngram function
df['tokens_ngrams'] = df['tokens'].apply(lambda tokens: ngram(tokens, n=2, sep=' ', stopwords=set()))
df['tokens_no_stopwords_ngrams'] = df['tokens_no_stopwords'].apply(lambda tokens: ngram(tokens, n=2, sep=' ', stopwords=set()))
df['tokens_regexp_ngrams'] = df['tokens_regexp'].apply(lambda tokens: ngram(tokens, n=2, sep=' ', stopwords=set()))

# %%
# Step 1: Flatten the list of bigrams
all_bigrams = [bigram for ngram_list in df['tokens_ngrams'] for bigram in ngram_list]

# Step 2: Count the occurrences of each bigram
bigram_counts = Counter(all_bigrams)

# Step 3: Sort the bigrams by count in descending order
sorted_bigrams = sorted(bigram_counts.items(), key=lambda x: x[1], reverse=True)

# Step 4: Select the top 10 bigrams
top_10_bigrams = sorted_bigrams[:10]

# Print the top 10 bigrams
for bigram, count in top_10_bigrams:
    print(f'Bigram: "{bigram}", Count: {count}')
# Out:
# Bigram: "of the", Count: 396731
# Bigram: "in the", Count: 143542
# Bigram: ". The", Count: 129332
# Bigram: "to the", Count: 117737
# Bigram: "United Nations", Count: 102500
# Bigram: "the United", Count: 94938
# Bigram: ", the", Count: 94463
# Bigram: ". We", Count: 92747
# Bigram: "and the", Count: 85711
# Bigram: "for the", Count: 64685

# %%
# Step 1: Flatten the list of bigrams
all_bigrams = [bigram for ngram_list in df['tokens_no_stopwords_ngrams'] for bigram in ngram_list]

# Step 2: Count the occurrences of each bigram
bigram_counts = Counter(all_bigrams)

# Step 3: Sort the bigrams by count in descending order
sorted_bigrams = sorted(bigram_counts.items(), key=lambda x: x[1], reverse=True)

# Step 4: Select the top 10 bigrams
top_10_bigrams = sorted_bigrams[:10]

# Print the top 10 bigrams
for bigram, count in top_10_bigrams:
    print(f'Bigram: "{bigram}", Count: {count}')
# Out:
# Bigram: "United Nations", Count: 102501
# Bigram: "international community", Count: 27653
# Bigram: "General Assembly", Count: 26980
# Bigram: "Security Council", Count: 20882
# Bigram: "developing countries", Count: 17969
# Bigram: "human rights", Count: 16054
# Bigram: "world .", Count: 14513
# Bigram: ". also", Count: 14118
# Bigram: "countries ,", Count: 13592
# Bigram: "peace security", Count: 13138

# %%
# Step 1: Flatten the list of bigrams
all_bigrams = [bigram for ngram_list in df['tokens_regexp_ngrams'] for bigram in ngram_list]

# Step 2: Count the occurrences of each bigram
bigram_counts = Counter(all_bigrams)

# Step 3: Sort the bigrams by count in descending order
sorted_bigrams = sorted(bigram_counts.items(), key=lambda x: x[1], reverse=True)

# Step 4: Select the top 10 bigrams
top_10_bigrams = sorted_bigrams[:10]

# Print the top 10 bigrams
for bigram, count in top_10_bigrams:
    print(f'Bigram: "{bigram}", Count: {count}')
# Out:
# Bigram: "Mr President", Count: 2035
# Bigram: "Mr Kofi Annan", Count: 402
# Bigram: "Mr Kurt Waldheim", Count: 398
# Bigram: "Mr Javier Perez de Cuellar", Count: 302
# Bigram: "Mr Boutros Boutros-Ghali", Count: 261
# Bigram: "﻿Mr President", Count: 177
# Bigram: "It is therefore", Count: 133
# Bigram: "Mr Ban Ki-moon", Count: 121
# Bigram: "We are however", Count: 98
# Bigram: "It is however", Count: 97

# %%
# Identify the cleaning points

# %%
# Conduct text cleaning

# %%
# Explore the word and character distribution
